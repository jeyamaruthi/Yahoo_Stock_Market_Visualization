# %%
import pandas as pd 
import pandas_datareader as dr
# %matplotlib inline

# %%
data_frame = dr.data.get_data_yahoo('ibm',start = '2020-03-21',end = '2020-03-31')

# %%
data_frame
# Out:
#                   High         Low        Open       Close   Volume  \
# Date
# 2020-03-23   97.739998   90.559998   94.599998   94.769997  9729400
# 2020-03-24  106.040001   99.260002   99.989998  105.480003  7973900
# 2020-03-25  112.480003  102.830002  105.480003  105.849998  8654000
# 2020-03-26  113.150002  105.570000  106.910004  112.889999  7153500
# 2020-03-27  111.500000  107.650002  108.580002  108.029999  6423000
# 2020-03-30  113.459999  107.809998  108.089996  112.930000  5562500
# 2020-03-31  113.809998  110.169998  112.000000  110.930000  6122562
#
#              Adj Close
# Date
# 2020-03-23   94.769997
# 2020-03-24  105.480003
# 2020-03-25  105.849998
# 2020-03-26  112.889999
# 2020-03-27  108.029999
# 2020-03-30  112.930000
# 2020-03-31  110.930000

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7 entries, 2020-03-23 to 2020-03-31
# Data columns (total 6 columns):
# High         7 non-null float64
# Low          7 non-null float64
# Open         7 non-null float64
# Close        7 non-null float64
# Volume       7 non-null int64
# Adj Close    7 non-null float64
# dtypes: float64(5), int64(1)
# memory usage: 392.0 bytes

# %%
data_frame[['Open','Close']].plot(figsize = (15,5));
